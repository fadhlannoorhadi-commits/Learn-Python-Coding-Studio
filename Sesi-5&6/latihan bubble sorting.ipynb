# %%
etalase = [{"nama": "AK-47", "harga": 2000},
{"nama": "grenade", "harga": 10000},
{"nama": "gas mask", "harga": 50000},
{"nama": "humvee", "harga": 700000},
]

def tampilkan_etalase(etalase):
   print("\n daftar produk:", etalase)
   for e in etalase:
      print(f"nama produk {e["nama"]}, harga produk {e["harga"]}")

def bubble_sort_by_nama(data_list):

    pjglist = len(data_list)
    
    for index in range (0, index - 1):
    
     for jindex in range(0,pjglist - index - 1):

        if pjglist[jindex]["nama"] > pjglist[jindex + 1]["nama"]:
           
           pjglist[jindex], pjglist[jindex + 1] = pjglist[jindex + 1], pjglist[jindex]
    
     return data_list 
    
 
def bubble_sort_by_harga (data_list):

    pjglist = len(data_list)
    
    for index in range (0, index - 1):
    
     for jindex in range(0,pjglist - index - 1):

        if pjglist[jindex]["harga"] > pjglist[jindex + 1]["harga"]:
           
           pjglist[jindex], pjglist[jindex + 1] = pjglist[jindex + 1], pjglist[jindex]
    
     return data_list 
    
def main():
     print("Welcome to the fucking death store")  

while True:
    print("\n1. urutkan berdasarkan nama")
    print("2. urutkan berdasarkan harga")
    print("3. tampilkan etalase")
    print("4. keluar")

    pilihan = input("pilih 1/2/3/4")

    if pilihan == "1":
         hasil = bubble_sort_by_nama(etalase)
         tampilkan_etalase(hasil)
    elif pilihan == "2":
        hasil = bubble_sort_by_harga (etalase)
        tampilkan_etalase(hasil)
    elif pilihan == "3":
        tampilkan_etalase (etalase)

    if pilihan == "4":
        break

main()
# Out:
# 1. urutkan berdasarkan nama
# 2. urutkan berdasarkan harga
# 3. tampilkan etalase
# 4. keluar
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[6], line 56
#      54      tampilkan_etalase(hasil)
#      55 elif pilihan == "2":
# ---> 56     hasil = bubble_sort_by_harga (etalase)
#      57     tampilkan_etalase(hasil)
#      58 elif pilihan == "3":
#
# Cell In[6], line 31, in bubble_sort_by_harga(data_list)
#      27 def bubble_sort_by_harga (data_list):
#      29     pjglist = len(data_list)
# ---> 31     for index in range (0, index - 1):
#      33      for jindex in range(0,pjglist - index - 1):
#      35         if pjglist[jindex]["harga"] > pjglist[jindex + 1]["harga"]:
#
# UnboundLocalError: cannot access local variable 'index' where it is not associated with a value
