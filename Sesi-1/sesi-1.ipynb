# %%
print("Hello World")
# Out:
# Hello World

# %%
# sequential => terurut
angka=10

hasil=angka * 20

print(hasil)
# Out:
# 200

# %%
# Selection =>Pemilihan
angka= 15

cek_angka % 2

if cek_angka == 0:
 print("Genap")
else: 
 print("Ganjil")
# Out:
#   Cell In[3], line 4
#     cek_angka modulus 2
#               ^
# SyntaxError: invalid syntax

# %%
# Iteration => 
for i in range (10):
    print("hello world")
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world

# %% [markdown]
# print (Kecil semua)
# Ipynb: phyton notebook
# IDE (Integrated Development Environment): Pycharm, Jupyter Notebook, Microsoft Visual Code
# Jenis Algoritma: Sequential, Selection, Iteration
# Sequential: mengeksekusi serangkaian intstruksi secara berurutan
# Selection
# Variable: cara menyimpan data untuk berbagai tipe data: bilangan bulat, teks, suatu kondisi, dll (kyk gelas kosong yang bisa diisi apa saja)
# Variable case sensitive: x/y
